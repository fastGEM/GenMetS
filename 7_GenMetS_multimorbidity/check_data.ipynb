# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/home/yurui/GenMetS/7_GenMetS_multimorbidity/UKB_Asianwomenmen_s8792_mets_diseases_others.txt', sep='\t')

# %%
female_df = df[df.sex == 'Female']

# %%
male_df = df[df.sex == 'Male']

# %%
female_df.__len__()
# Out:
# 4189

# %%
male_df.multimorbidity.value_counts()
# Out:
# multimorbidity
# 0.0    3059
# 1.0    1233
# Name: count, dtype: int64

# %%
df.multimorbidity.value_counts()
# Out:
# multimorbidity
# 0.0    6360
# 1.0    1942
# Name: count, dtype: int64

# %%
from utils import *
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
target_col = 'multimorbidity'
covariates = [
    "GenMetS", "TVhour", "Sleephour", "PhysicalActivity",
    "SocialEconomicalStatus", "Age", "Education"
]
X_train, y_train, X_test, y_test = prepare_data(female_df, target_col, covariates, seed=3)
# Out:
# multimorbidity
# 1.0    460
# 0.0    460
# Name: count, dtype: int64
# GenMetS                   float64
# TVhour                    float64
# Sleephour                 float64
# PhysicalActivity          float64
# SocialEconomicalStatus    float64
# Age                         int64
# dtype: object
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 0.74038589  0.36791561 -1.74274929  0.86454265 -0.99780874 -0.37702494
#   0.49207237  0.61622913 -0.00455466 -0.25286818 -1.37027901  1.23701293
#  -0.37702494 -0.12871142 -0.62533846  1.6094832   1.48532644 -0.12871142
#  -0.99780874 -1.24612225 -1.74274929 -0.12871142  0.36791561 -0.62533846
#  -0.99780874  0.1196021  -1.61859253  1.6094832  -1.86690605 -0.62533846
#  -1.61859253 -1.74274929 -0.87365198 -0.74949522 -0.12871142 -0.37702494
#  -1.12196549 -1.61859253 -0.12871142 -1.12196549  0.86454265 -0.74949522
# ...

# %%
y_train.value_counts()
# Out:
# multimorbidity
# 0.0    368
# 1.0    368
# Name: count, dtype: int64

# %%
y_test.value_counts()
# Out:
# multimorbidity
# 1.0    92
# 0.0    92
# Name: count, dtype: int64

# %%
368+92
# Out:
# 460

# %%
X_train, y_train, X_test, y_test = prepare_data(male_df, target_col, covariates, seed=3)
# Out:
# multimorbidity
# 1.0    884
# 0.0    884
# Name: count, dtype: int64
# GenMetS                   float64
# TVhour                    float64
# Sleephour                 float64
# PhysicalActivity          float64
# SocialEconomicalStatus    float64
# Age                         int64
# dtype: object
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-1.19883369  1.24643129  0.89710772 ...  0.43134296  1.01354891
#  -0.38374536]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
# Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[-1.66459845  0.0820194  -0.38374536 -0.15086298  1.36287248 -0.38374536
#   1.59575486 -0.03442179  1.01354891  0.78066653  0.0820194   0.89710772
#   0.31490177  1.24643129 -1.19883369  0.66422534 -0.73306893 -0.96595131
#   0.31490177 -0.84951012 -1.54815726 -1.54815726 -0.61662774  1.01354891
# ...

# %%
y_train.value_counts()
# Out:
# multimorbidity
# 0.0    707
# 1.0    707
# Name: count, dtype: int64
